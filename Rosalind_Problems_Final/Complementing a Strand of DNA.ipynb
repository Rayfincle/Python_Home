# %%
DNA = input()
# Out:
# ...

# %%
reverse_DNA = DNA[::-1]
complement = reverse_DNA.replace("T" , "Y").replace("G" , "Z").replace("C" , "G").replace("A" , "T").replace("Y" , "A").replace("Z" , "C")
print(complement)
# Out:
# ...
